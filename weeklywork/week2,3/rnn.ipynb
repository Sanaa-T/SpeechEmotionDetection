# %% [markdown]
# This time we will be implementing an RNN model.
#
# Time series forcasting is an important topic in Machine Learning.\
# In this, we will are given the data for sunspots from jan 1749 to dec 1983.\
# we will be dividing this data in to two parts, one for training our model and second for testing our model.\
# In time series forcasting, we will have to take continuous data and not randomized data, because we have to predict on the basis of given past data.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# We will have to take the data from the url given.
#
# You have to implement the get_train_test function and return train_data and test_data, scaled in the range [0,1]
#
# To scale the data, read on MinMaxScalar class in sklearn.preprocessing
#
# Testing data should be the first 80 percent values and rest should be testing data. Also, convert the index of the data to datetime

# %%
from sklearn.preprocessing import MinMaxScaler
def get_train_test(url):
    df = pd.read_csv(url, index_col='Month', parse_dates=True)
    df.index.freq = 'MS'

    N = len(df)
    Tp = int(N*0.8)

    train = df.iloc[:Tp]
    test = df.iloc[Tp:]

    scaler = MinMaxScaler()
    scaler.fit(train)
    train_data = scaler.transform(train)
    test_data = scaler.transform(test)

    # Clamping the test data values to the range [0,1]
    test_data = np.clip(test_data, 0, 1)
    
    return train_data, test_data
    pass

# %% [markdown]
# Now we will take the data from your implemented function :)

# %%
sunspots_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv'
train_data, test_data = get_train_test(sunspots_url)

# print(train_data)
# print(test_data)

X_train = train_data[:-1]
y_train = train_data[1:]

X_test = test_data[:-1]
y_test = test_data[1:]

# %% [markdown]
# Now let's make the model for our computations.
#
# The model will consist of a layer of RNN of 64 nodes followed by a layer of Feed Forward Neural Network of one output node.
#
# For compiling the node, we will use mean squared error as loss and mean absolute error as metric. We will not use accuracy as the metric. Think on why :)

# %%
# make the model .... all the best
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

model = Sequential()
model.add(SimpleRNN(units=64, input_shape=(1, 1), activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()

# train the model on the X_train dataset
X_train_reshaped = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

model.fit(X_train_reshaped, y_train, epochs=50, batch_size=32, verbose=1)

# predict the values for training and testing data
train_predict = model.predict(X_train_reshaped)
test_predict = model.predict(X_test_reshaped)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_6 (SimpleRNN)        │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 792us/step - loss: 0.0290 - mean_absolute_error: 0.1205
# Epoch 2/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.0068 - mean_absolute_error: 0.0628
# Epoch 3/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0494
# Epoch 4/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 0.0045 - mean_absolute_error: 0.0479
# Epoch 5/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 0.0042 - mean_absolute_error: 0.0460
# Epoch 6/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.0045 - mean_absolute_error: 0.0470
# Epoch 7/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0041 - mean_absolute_error: 0.0461
# Epoch 8/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0046 - mean_absolute_error: 0.0479
# Epoch 9/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0046 - mean_absolute_error: 0.0474
# Epoch 10/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0044 - mean_absolute_error: 0.0472
# Epoch 11/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0471
# Epoch 12/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0477
# Epoch 13/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0478
# Epoch 14/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0045 - mean_absolute_error: 0.0482
# Epoch 15/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.0045 - mean_absolute_error: 0.0478
# Epoch 16/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - loss: 0.0042 - mean_absolute_error: 0.0468
# Epoch 17/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.0049 - mean_absolute_error: 0.0488
# Epoch 18/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.0043 - mean_absolute_error: 0.0457
# Epoch 19/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0044 - mean_absolute_error: 0.0474
# Epoch 20/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.0043 - mean_absolute_error: 0.0471
# Epoch 21/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.0045 - mean_absolute_error: 0.0469
# Epoch 22/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 0.0045 - mean_absolute_error: 0.0471
# Epoch 23/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - loss: 0.0044 - mean_absolute_error: 0.0464
# Epoch 24/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - loss: 0.0048 - mean_absolute_error: 0.0492
# Epoch 25/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0044 - mean_absolute_error: 0.0462
# Epoch 26/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0043 - mean_absolute_error: 0.0468
# Epoch 27/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 0.0045 - mean_absolute_error: 0.0464
# Epoch 28/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - loss: 0.0048 - mean_absolute_error: 0.0487
# Epoch 29/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.0045 - mean_absolute_error: 0.0476
# Epoch 30/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.0046 - mean_absolute_error: 0.0484
# Epoch 31/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.0047 - mean_absolute_error: 0.0474
# Epoch 32/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.0046 - mean_absolute_error: 0.0476
# Epoch 33/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mean_absolute_error: 0.0470
# Epoch 34/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0044 - mean_absolute_error: 0.0461
# Epoch 35/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 0.0045 - mean_absolute_error: 0.0471
# Epoch 36/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0045 - mean_absolute_error: 0.0476
# Epoch 37/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0042 - mean_absolute_error: 0.0463
# Epoch 38/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.0040 - mean_absolute_error: 0.0460
# Epoch 39/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.0046 - mean_absolute_error: 0.0470
# Epoch 40/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.0046 - mean_absolute_error: 0.0488
# Epoch 41/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.0051 - mean_absolute_error: 0.0500
# Epoch 42/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0041 - mean_absolute_error: 0.0457
# Epoch 43/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.0041 - mean_absolute_error: 0.0458
# Epoch 44/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.0043 - mean_absolute_error: 0.0466
# Epoch 45/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.0047 - mean_absolute_error: 0.0483
# Epoch 46/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.0044 - mean_absolute_error: 0.0464
# Epoch 47/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.0044 - mean_absolute_error: 0.0477
# Epoch 48/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.0048 - mean_absolute_error: 0.0487
# Epoch 49/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0041 - mean_absolute_error: 0.0458
# Epoch 50/50
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.0047 - mean_absolute_error: 0.0484
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step

# %% [markdown]
# Now let's print out what you have done :)

# %%
import math
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

   
train_rmse = math.sqrt(mean_squared_error(y_train, train_predict))
test_rmse = math.sqrt(mean_squared_error(y_test, test_predict))
# Print RMSE
print('Train RMSE: %.3f RMSE' % (train_rmse))
print('Test RMSE: %.3f RMSE' % (test_rmse))    

actual = np.append(y_train, y_test)
predictions = np.append(train_predict, test_predict)
rows = len(actual)
plt.figure(figsize=(15, 6), dpi=120)
plt.plot(range(rows), actual)
plt.plot(range(rows), predictions)
plt.axvline(x=len(y_train), color='r')
plt.legend(['Actual', 'Predictions'])
plt.xlabel('Observation number after given time steps')
plt.ylabel('Sunspots scaled')
plt.title('Actual and Predicted Values. The Red Line Separates The Training And Test Examples')
# Out:
# Train RMSE: 0.067 RMSE
# Test RMSE: 0.089 RMSE
# Text(0.5, 1.0, 'Actual and Predicted Values. The Red Line Separates The Training And Test Examples')
